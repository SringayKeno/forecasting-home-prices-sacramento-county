# %% [markdown]
# #### import libraries

# %%
import pandas as p
import numpy as np
import pickle
import emoji

# %% [markdown]
# #####  import pickle
#   * ##### *pickle module implements binary protocols for serializing and de-serializing a*
#    ##### *python object structure. “pickling” is the process whereby a python object hierarchy is*
#    ##### *converted into a byte stream*

# %% [markdown]
# #### let's load some data!

# %%
df=p.read_csv('ZHIV_zip_.csv')
df.head(3)
# Out:
#    RegionID  SizeRank  RegionName RegionType StateName State      City  \
# 0     61639         0       10025        Zip        NY    NY  New York
# 1     84654         1       60657        Zip        IL    IL   Chicago
# 2     61637         2       10023        Zip        NY    NY  New York
#
#                          Metro       CountyName  2000-01-31  ...  2021-10-31  \
# 0  New York-Newark-Jersey City  New York County    329164.0  ...   1153364.0
# 1     Chicago-Naperville-Elgin      Cook County    311718.0  ...    523727.0
# 2  New York-Newark-Jersey City  New York County    510209.0  ...   1517150.0
#
#    2021-11-30  2021-12-31  2022-01-31  2022-02-28  2022-03-31  2022-04-30  \
# 0   1152736.0   1153314.0   1159292.0   1171216.0   1190200.0   1207107.0
# 1    526511.0    528499.0    529879.0    530092.0    532758.0    534840.0
# 2   1521442.0   1521759.0   1532449.0   1542269.0   1559390.0   1572653.0
#
#    2022-05-31  2022-06-30  2022-07-31
# ...

# %% [markdown]
# ####   export metaData w pickles  🥒
#
# * #### removing region data iloc[:, 0:9]
# * #### check column (cols)
# * ####    import os.mkdir()
#     * ##### *mkdir is used for creating or making a new directory*
# * ####    dump metaData

# %%
meta = df.iloc[:, 0:9]

# %%
meta.columns
# Out:
# Index(['RegionID', 'SizeRank', 'RegionName', 'RegionType', 'StateName',
#        'State', 'City', 'Metro', 'CountyName'],
#       dtype='object')

# %%
#import os
#os.mkdir('pickles')

# %%
with open('pickles/meta.pkl', 'wb') as fp:
    pickle.dump(meta, fp)

# %% [markdown]
# #### subset df sacramento
# #### sacramento=sac

# %%
sac = df[df.CountyName == 'Sacramento County']

# %%
meta_cols = list(df.columns[0:9])

# %%
meta_cols.remove('RegionName')

# %%
sac = sac.drop(meta_cols, axis = 1)

# %% [markdown]
# #### examine data

# %%
sac.shape
# Out:
# (50, 272)

# %%
sac.head(10)
# Out:
#       RegionName  2000-01-31  2000-02-29  2000-03-31  2000-04-30  2000-05-31  \
# 102        95630    235832.0    236836.0    237997.0    240134.0    242395.0
# 163        95608    174288.0    175027.0    175987.0    177583.0    179274.0
# 187        95823    114478.0    114963.0    115594.0    116743.0    117922.0
# 376        95758    172491.0    173242.0    174209.0    175923.0    177760.0
# 506        95670    151622.0    152162.0    152938.0    154300.0    155740.0
# 776        95624    188868.0    189591.0    190462.0    192080.0    193869.0
# 1045       95831    183734.0    184517.0    185582.0    187258.0    189063.0
# 1066       95828    127990.0    128557.0    129151.0    130358.0    131677.0
# 1153       95628    194236.0    195146.0    196134.0    197833.0    199806.0
# 1187       95610    151719.0    152299.0    152998.0    154388.0    156028.0
#
#       2000-06-30  2000-07-31  2000-08-31  2000-09-30  ...  2021-10-31  \
# ...

# %% [markdown]
# #### nulls? if so, how many?

# %%
sac.isna().sum().sum()
# Out:
# 135

# %% [markdown]
# #### nulls. which columns?

# %%
sac.isna().any()
# Out:
# RegionName    False
# 2000-01-31     True
# 2000-02-29     True
# 2000-03-31     True
# 2000-04-30     True
#               ...
# 2022-03-31    False
# 2022-04-30    False
# 2022-05-31    False
# 2022-06-30    False
# 2022-07-31    False
# Length: 272, dtype: bool

# %% [markdown]
# #### nulls. which rows?

# %%
sac[sac.isna().any(axis=1)]
# Out:
#        RegionName  2000-01-31  2000-02-29  2000-03-31  2000-04-30  2000-05-31  \
# 4720        95824     96280.0     96456.0     96817.0     97323.0     98136.0
# 9318        95742         NaN         NaN         NaN         NaN         NaN
# 11120       95832    127229.0    127814.0    128346.0    129255.0    129962.0
# 14695       95655         NaN         NaN         NaN         NaN         NaN
#
#        2000-06-30  2000-07-31  2000-08-31  2000-09-30  ...  2021-10-31  \
# 4720      99043.0    100753.0    102337.0    103864.0  ...    350709.0
# 9318          NaN         NaN         NaN         NaN  ...    615853.0
# 11120    130884.0    131874.0    133181.0    134297.0  ...    390735.0
# 14695         NaN         NaN         NaN         NaN  ...    555334.0
#
#        2021-11-30  2021-12-31  2022-01-31  2022-02-28  2022-03-31  2022-04-30  \
# 4720     352093.0    353775.0    359113.0    365366.0    371287.0    376263.0
# ...

# %% [markdown]
# #### nulls. closer low at one col with nulls. zipCode 95655 (mather ca)

# %%
print(sac.loc[[14695]])
# Out:
#        RegionName  2000-01-31  2000-02-29  2000-03-31  2000-04-30  2000-05-31  \
# 14695       95655         NaN         NaN         NaN         NaN         NaN
#
#        2000-06-30  2000-07-31  2000-08-31  2000-09-30  ...  2021-10-31  \
# 14695         NaN         NaN         NaN         NaN  ...    555334.0
#
#        2021-11-30  2021-12-31  2022-01-31  2022-02-28  2022-03-31  2022-04-30  \
# 14695    558488.0    562731.0    571954.0    582411.0    591254.0    598666.0
#
#        2022-05-31  2022-06-30  2022-07-31
# 14695    606136.0    611227.0    609348.0
#
# [1 rows x 272 columns]

# %% [markdown]
# #### nulls. closer low at one col with nulls. zipCode 95742 (rancho coradova ca).
# #### which is right next to mather ca

# %%
print(sac.loc[[9318]])
# Out:
#       RegionName  2000-01-31  2000-02-29  2000-03-31  2000-04-30  2000-05-31  \
# 9318       95742         NaN         NaN         NaN         NaN         NaN
#
#       2000-06-30  2000-07-31  2000-08-31  2000-09-30  ...  2021-10-31  \
# 9318         NaN         NaN         NaN         NaN  ...    615853.0
#
#       2021-11-30  2021-12-31  2022-01-31  2022-02-28  2022-03-31  2022-04-30  \
# 9318    621054.0    626863.0    637645.0    649459.0    660568.0    671286.0
#
#       2022-05-31  2022-06-30  2022-07-31
# 9318    681191.0    688780.0    687901.0
#
# [1 rows x 272 columns]

# %% [markdown]
# #### mather and rancho cordova zip codes are focus zip codes, but most of the nans are in those columns up until 2010. i'd have t drop 1/2 the columns. instead, I will examine those zips later

# %%
sac=sac.drop(9318)

# %%
sac=sac.drop(14695)

# %% [markdown]
# #### nulls. what do we have left?

# %%
sac.isna().sum().sum()
# Out:
# 2

# %% [markdown]
# #### 2 nans yet! disappointing actually
# #### let's look at remaining nans

# %%
sac2 = sac[sac.isna().any(axis=1)]
sac2
# Out:
#        RegionName  2000-01-31  2000-02-29  2000-03-31  2000-04-30  2000-05-31  \
# 4720        95824     96280.0     96456.0     96817.0     97323.0     98136.0
# 11120       95832    127229.0    127814.0    128346.0    129255.0    129962.0
#
#        2000-06-30  2000-07-31  2000-08-31  2000-09-30  ...  2021-10-31  \
# 4720      99043.0    100753.0    102337.0    103864.0  ...    350709.0
# 11120    130884.0    131874.0    133181.0    134297.0  ...    390735.0
#
#        2021-11-30  2021-12-31  2022-01-31  2022-02-28  2022-03-31  2022-04-30  \
# 4720     352093.0    353775.0    359113.0    365366.0    371287.0    376263.0
# 11120    392838.0    394673.0    400416.0    406873.0    413608.0    419317.0
#
#        2022-05-31  2022-06-30  2022-07-31
# 4720     381388.0    385475.0    385612.0
# 11120    424165.0    427472.0    427186.0
#
# [2 rows x 272 columns]

# %% [markdown]
# #### since only 2 nans and they are not next to each other lets ffill

# %%
sac.ffill(axis=0, inplace=True, limit=2)

# %% [markdown]
# #### get a count of nans

# %%
sac.isna().sum().sum()
# Out:
# 0

# %% [markdown]
# #### ok, quick last check

# %%
sac.head()
# Out:
#      RegionName  2000-01-31  2000-02-29  2000-03-31  2000-04-30  2000-05-31  \
# 102       95630    235832.0    236836.0    237997.0    240134.0    242395.0
# 163       95608    174288.0    175027.0    175987.0    177583.0    179274.0
# 187       95823    114478.0    114963.0    115594.0    116743.0    117922.0
# 376       95758    172491.0    173242.0    174209.0    175923.0    177760.0
# 506       95670    151622.0    152162.0    152938.0    154300.0    155740.0
#
#      2000-06-30  2000-07-31  2000-08-31  2000-09-30  ...  2021-10-31  \
# 102    244414.0    247327.0    250195.0    253888.0  ...    740474.0
# 163    180558.0    182109.0    183630.0    185658.0  ...    552793.0
# 187    118973.0    120408.0    121793.0    123521.0  ...    414301.0
# 376    179344.0    181311.0    183272.0    185460.0  ...    563435.0
# 506    156682.0    157906.0    159379.0    161537.0  ...    471998.0
#
#      2021-11-30  2021-12-31  2022-01-31  2022-02-28  2022-03-31  2022-04-30  \
# ...

# %% [markdown]
# #### calculate percent increase from yr to yr in sac

# %%
def calculate_percent_increase(x1, x2):
    return ((x2-x1)/x1)*100

# %%
sac_p = sac.copy()
for i in range(sac_p.shape[1]-1,1, -1):
    prior = sac_p.iloc[:, i-1]
    current = sac_p.iloc[:, i] 
    sac_p.iloc[:, i] = calculate_percent_increase(prior, current)

# %% [markdown]
# #### look at percent increase

# %%
sac_p.head()
# Out:
#      RegionName  2000-01-31  2000-02-29  2000-03-31  2000-04-30  2000-05-31  \
# 102       95630    235832.0    0.425727    0.490213    0.897910    0.941558
# 163       95608    174288.0    0.424011    0.548487    0.906885    0.952231
# 187       95823    114478.0    0.423662    0.548872    0.993996    1.009911
# 376       95758    172491.0    0.435385    0.558179    0.983876    1.044207
# 506       95670    151622.0    0.356149    0.509983    0.890557    0.933247
#
#      2000-06-30  2000-07-31  2000-08-31  2000-09-30  ...  2021-10-31  \
# 102    0.832938    1.191830    1.159598    1.476049  ...    0.400940
# 163    0.716222    0.859004    0.835214    1.104395  ...    0.072956
# 187    0.891267    1.206156    1.150256    1.418801  ...    0.742864
# 376    0.891089    1.096775    1.081567    1.193854  ...    0.924095
# 506    0.604854    0.781200    0.932833    1.354005  ...    0.453319
#
#      2021-11-30  2021-12-31  2022-01-31  2022-02-28  2022-03-31  2022-04-30  \
# ...

# %% [markdown]
# #### transpose data

# %%
sac_p = sac_p.set_index('RegionName').transpose()

# %%
sac = sac.set_index('RegionName').transpose()

# %% [markdown]
# #### fix datetime

# %%
sac_p.index = p.DatetimeIndex(sac_p.index)
sac_p.index = sac_p.index.strftime('%m/%Y')
sac_p.columns.name = None

# %%
sac.index = p.DatetimeIndex(sac.index)
sac.index = sac.index.strftime('%m/%Y')
sac.columns.name = None

# %% [markdown]
# #### exporting 🥒

# %%
with open('pickles/timeseries_sac_p.pkl', 'wb') as fp:
    pickle.dump(sac_p, fp)

# %%
with open('pickles/timeseries_sac.pkl', 'wb') as fp:
    pickle.dump(sac, fp)

# %%
sac_p.to_csv('timeseries_sac_p.csv', header=True)
