# %% [markdown]
#  import libraries

# %% [markdown]
#   import pickle
#  *  *pickle module implements binary protocols for serializing and de-serializing a*
#     *python object structure. “pickling” is the process whereby a python object hierarchy is*
#     *converted into a byte stream*

# %%
import pandas as p
import numpy as np
import pickle
import emoji

# %% [markdown]
#  let's load some data!

# %%
df=p.read_csv('two_bedroom_zhiv.csv')
df.head(3)
# Out:
#    RegionID  SizeRank  RegionName RegionType StateName State           City  \
# 0     70603      8297       29620        zip        SC    SC      Abbeville
# 1     70619     13371       29638        zip        SC    SC        Donalds
# 2     70611     18074       29628        zip        SC    SC  Calhoun Falls
#
#   Metro        CountyName  1/31/2000  ...  11/30/2021  12/31/2021  1/31/2022  \
# 0   NaN  Abbeville County        NaN  ...     90999.0     93095.0    94953.0
# 1   NaN  Abbeville County        NaN  ...     94231.0     96561.0    96838.0
# 2   NaN  Abbeville County        NaN  ...         NaN         NaN        NaN
#
#    2/28/2022  3/31/2022  4/30/2022  5/31/2022  6/30/2022  7/31/2022  8/31/2022
# 0    97160.0    97953.0    99287.0   100451.0   102284.0   103700.0   104206.0
# 1    98317.0    98418.0   100449.0   101960.0   104057.0   105318.0   104912.0
# 2        NaN        NaN        NaN        NaN        NaN        NaN    46234.0
#
# [3 rows x 281 columns]

# %% [markdown]
#  export metaData w pickles  🥒
#
# *  removing region data- iloc[:, 0:9]
# *  check column (cols)
# *     import os.mkdir()
#    *  *mkdir is used for creating or making a new directory*
# *     dump metaData
#   *  'wb' for writing binary file.
#   *  'fp' file pointer

# %%
meta = df.iloc[:, 0:9]

# %%
meta.columns
# Out:
# Index(['RegionID', 'SizeRank', 'RegionName', 'RegionType', 'StateName',
#        'State', 'City', 'Metro', 'CountyName'],
#       dtype='object')

# %%
#import os
#os.mkdir('pickle')

# %%
with open('pickle/meta_two_bedroom.pkl', 'wb') as fp:
    pickle.dump(meta, fp)

# %% [markdown]
#  subsetting
# *  creating sac (sacramento) dataFrame
# *  get list
# *  remove col RegionName
# *  drop cols (columns)

# %%
subset = df[df.CountyName == 'Sacramento County']

# %%
meta_cols = list(df.columns[0:9])

# %%
meta_cols.remove('RegionName')

# %%
subset = subset.drop(meta_cols, axis = 1)

# %% [markdown]
#  examine data

# %%
subset.shape
# Out:
# (45, 273)

# %%
subset.head(3)
# Out:
#        RegionName  1/31/2000  2/29/2000  3/31/2000  4/30/2000  5/31/2000  \
# 14669       95823    78510.0    78708.0    79207.0    80015.0    80789.0
# 14670       95630   142002.0   142603.0   143167.0   144346.0   145810.0
# 14671       95624   107971.0   107999.0   108534.0   108888.0   110386.0
#
#        6/30/2000  7/31/2000  8/31/2000  9/30/2000  ...  11/30/2021  \
# 14669    80966.0    81734.0    82611.0    84323.0  ...    304587.0
# 14670   147597.0   149671.0   151280.0   152986.0  ...    485104.0
# 14671   110993.0   112468.0   113624.0   115610.0  ...    388332.0
#
#        12/31/2021  1/31/2022  2/28/2022  3/31/2022  4/30/2022  5/31/2022  \
# 14669    307733.0   313684.0   319451.0   324447.0   329735.0   335108.0
# 14670    487226.0   494307.0   503272.0   511583.0   518097.0   524843.0
# 14671    385042.0   388176.0   392381.0   397793.0   405103.0   412687.0
#
#        6/30/2022  7/31/2022  8/31/2022
# 14669   339946.0   340896.0   336388.0
# 14670   529819.0   528624.0   519360.0
# 14671   419169.0   421156.0   416847.0
#
# [3 rows x 273 columns]

# %% [markdown]
#  nulls? if so, how many?

# %%
subset.isna().sum().sum()
# Out:
# 447

# %% [markdown]
#  nulls? which columns?

# %%
subset.isna().any()
# Out:
# RegionName    False
# 1/31/2000      True
# 2/29/2000      True
# 3/31/2000      True
# 4/30/2000      True
#               ...
# 4/30/2022     False
# 5/31/2022     False
# 6/30/2022     False
# 7/31/2022     False
# 8/31/2022     False
# Length: 273, dtype: bool

# %% [markdown]
#  nulls? which rows?

# %%
subset[subset.isna().any(axis=1)]
# Out:
#        RegionName  1/31/2000  2/29/2000  3/31/2000  4/30/2000  5/31/2000  \
# 14676       95757        NaN        NaN        NaN        NaN        NaN
# 14683       95835        NaN        NaN        NaN        NaN        NaN
# 14706       95832        NaN        NaN        NaN        NaN        NaN
# 14707       95814        NaN        NaN        NaN        NaN        NaN
# 14713       95641        NaN        NaN        NaN        NaN        NaN
#
#        6/30/2000  7/31/2000  8/31/2000  9/30/2000  ...  11/30/2021  \
# 14676        NaN        NaN        NaN        NaN  ...    506595.0
# 14683        NaN        NaN        NaN        NaN  ...    441350.0
# 14706        NaN        NaN        NaN        NaN  ...    373338.0
# 14707        NaN        NaN        NaN        NaN  ...    535526.0
# 14713        NaN        NaN        NaN        NaN  ...    363642.0
#
#        12/31/2021  1/31/2022  2/28/2022  3/31/2022  4/30/2022  5/31/2022  \
# 14676    508990.0   518783.0   531115.0   543065.0   554203.0   563467.0
# 14683    443909.0   450397.0   457147.0   463603.0   469709.0   476095.0
# 14706    375102.0   379759.0   381338.0   387285.0   392888.0   401306.0
# 14707    531409.0   533484.0   537365.0   542871.0   546656.0   549014.0
# 14713    366225.0   370441.0   374404.0   379351.0   380270.0   385850.0
#
#        6/30/2022  7/31/2022  8/31/2022
# 14676   572696.0   571247.0   563504.0
# 14683   481261.0   480332.0   471931.0
# 14706   403322.0   401128.0   391551.0
# 14707   549545.0   551799.0   543682.0
# 14713   388752.0   392019.0   384474.0
#
# [5 rows x 273 columns]

# %% [markdown]
# mainly- nulls are in 5 rows. Going thru each zip individually to see what is case. Some zips can be droped entirely- too much missing data / or very rural (not many homes)

# %%
subset = subset.drop(14676)

# %%
subset=subset.drop(14706)

# %%
subset.isna().sum().sum()
# Out:
# 113

# %%
subset.drop(subset.iloc[:,1:48], inplace=True, axis=1)

# %% [markdown]
#  nulls. what do we have left?

# %%
subset.isna().sum().sum()
# Out:
# 1

# %%
subset.head(8)
# Out:
#        RegionName  12/31/2003  1/31/2004  2/29/2004  3/31/2004  4/30/2004  \
# 14669       95823    164193.0   166601.0   169264.0   171857.0   174169.0
# 14670       95630    252759.0   254797.0   257940.0   261322.0   263765.0
# 14671       95624    199456.0   203104.0   206791.0   210230.0   213436.0
# 14672       95758    243115.0   245903.0   249049.0   252310.0   254449.0
# 14673       95608    205997.0   209331.0   212500.0   215963.0   218176.0
# 14674       95828    194670.0   197201.0   199791.0   202764.0   205390.0
# 14675       95670    238307.0   241035.0   244081.0   247512.0   249865.0
# 14677       95843    176481.0   178957.0   181549.0   183986.0   185519.0
#
#        5/31/2004  6/30/2004  7/31/2004  8/31/2004  ...  11/30/2021  \
# 14669   177386.0   181122.0   186542.0   191364.0  ...    304587.0
# 14670   267825.0   272816.0   281133.0   288038.0  ...    485104.0
# 14671   217575.0   222053.0   228332.0   234024.0  ...    388332.0
# 14672   257804.0   261914.0   268919.0   275348.0  ...    428532.0
# 14673   221594.0   225994.0   232124.0   237401.0  ...    375420.0
# 14674   209567.0   214125.0   220552.0   226323.0  ...    329289.0
# 14675   253615.0   258145.0   264856.0   271200.0  ...    373116.0
# 14677   188527.0   192482.0   198293.0   202911.0  ...    344366.0
#
#        12/31/2021  1/31/2022  2/28/2022  3/31/2022  4/30/2022  5/31/2022  \
# 14669    307733.0   313684.0   319451.0   324447.0   329735.0   335108.0
# 14670    487226.0   494307.0   503272.0   511583.0   518097.0   524843.0
# 14671    385042.0   388176.0   392381.0   397793.0   405103.0   412687.0
# 14672    432318.0   440518.0   449369.0   458547.0   465834.0   472005.0
# 14673    376015.0   381711.0   388239.0   395407.0   400642.0   406120.0
# 14674    330296.0   334937.0   340508.0   346467.0   351959.0   357802.0
# 14675    375338.0   380360.0   385865.0   391877.0   397021.0   401685.0
# 14677    345690.0   351517.0   357186.0   363683.0   368939.0   374731.0
#
#        6/30/2022  7/31/2022  8/31/2022
# 14669   339946.0   340896.0   336388.0
# 14670   529819.0   528624.0   519360.0
# 14671   419169.0   421156.0   416847.0
# 14672   475336.0   472352.0   463733.0
# 14673   408772.0   408762.0   401915.0
# 14674   361043.0   360612.0   354406.0
# 14675   403901.0   402990.0   396821.0
# 14677   378937.0   377918.0   372320.0
#
# [8 rows x 226 columns]

# %% [markdown]
#  let's look at remaining nans

# %%
one_null = subset[subset.isna().any(axis=1)]
one_null
# Out:
#        RegionName  12/31/2003  1/31/2004  2/29/2004  3/31/2004  4/30/2004  \
# 14713       95641    218840.0   222860.0   225659.0   226696.0   227460.0
#
#        5/31/2004  6/30/2004  7/31/2004  8/31/2004  ...  11/30/2021  \
# 14713   229107.0   230478.0   231595.0   230425.0  ...    363642.0
#
#        12/31/2021  1/31/2022  2/28/2022  3/31/2022  4/30/2022  5/31/2022  \
# 14713    366225.0   370441.0   374404.0   379351.0   380270.0   385850.0
#
#        6/30/2022  7/31/2022  8/31/2022
# 14713   388752.0   392019.0   384474.0
#
# [1 rows x 226 columns]

# %% [markdown]
#  since only 1 nan lets ffill

# %%
subset.ffill(axis=0, inplace=True, limit=2)

# %% [markdown]
#  get a count of nans

# %%
subset.isna().sum().sum()
# Out:
# 0

# %% [markdown]
#  calculate percent increase from yr to yr in sac
# *  create df and define func (function)
# *  create copy
#    *  copy() method creates a copy of an existing list

# %%
def calculate_percent_increase(x1, x2):
    return ((x2-x1)/x1)*100

# %%
subset_percent = subset.copy()
for i in range(subset_percent.shape[1]-1,1, -1):
    prior = subset_percent.iloc[:, i-1]
    current = subset_percent.iloc[:, i] 
    subset_percent.iloc[:, i] = calculate_percent_increase(prior, current)

# %%
subset_percent.head(3)
# Out:
#        RegionName  12/31/2003  1/31/2004  2/29/2004  3/31/2004  4/30/2004  \
# 14669       95823    164193.0   1.466567   1.598430   1.531926   1.345305
# 14670       95630    252759.0   0.806302   1.233531   1.311158   0.934862
# 14671       95624    199456.0   1.828975   1.815326   1.663032   1.524996
#
#        5/31/2004  6/30/2004  7/31/2004  8/31/2004  ...  11/30/2021  \
# 14669   1.847057   2.106141   2.992458   2.584941  ...    1.089933
# 14670   1.539249   1.863530   3.048575   2.456133  ...    0.390092
# 14671   1.939223   2.058141   2.827703   2.492861  ...   -0.597950
#
#        12/31/2021  1/31/2022  2/28/2022  3/31/2022  4/30/2022  5/31/2022  \
# 14669    1.032874   1.933819   1.838474   1.563933   1.629850   1.629490
# 14670    0.437432   1.453330   1.813650   1.651393   1.273303   1.302073
# 14671   -0.847213   0.813937   1.083272   1.379272   1.837639   1.872116
#
#        6/30/2022  7/31/2022  8/31/2022
# 14669   1.443714   0.279456  -1.322397
# 14670   0.948093  -0.225549  -1.752474
# 14671   1.570682   0.474033  -1.023136
#
# [3 rows x 226 columns]

# %%
subset_percent.drop('12/31/2003' ,axis=1, inplace=True)

# %%
subset_percent.head(3)
# Out:
#        RegionName  1/31/2004  2/29/2004  3/31/2004  4/30/2004  5/31/2004  \
# 14669       95823   1.466567   1.598430   1.531926   1.345305   1.847057
# 14670       95630   0.806302   1.233531   1.311158   0.934862   1.539249
# 14671       95624   1.828975   1.815326   1.663032   1.524996   1.939223
#
#        6/30/2004  7/31/2004  8/31/2004  9/30/2004  ...  11/30/2021  \
# 14669   2.106141   2.992458   2.584941   2.547501  ...    1.089933
# 14670   1.863530   3.048575   2.456133   2.284074  ...    0.390092
# 14671   2.058141   2.827703   2.492861   2.363860  ...   -0.597950
#
#        12/31/2021  1/31/2022  2/28/2022  3/31/2022  4/30/2022  5/31/2022  \
# 14669    1.032874   1.933819   1.838474   1.563933   1.629850   1.629490
# 14670    0.437432   1.453330   1.813650   1.651393   1.273303   1.302073
# 14671   -0.847213   0.813937   1.083272   1.379272   1.837639   1.872116
#
#        6/30/2022  7/31/2022  8/31/2022
# 14669   1.443714   0.279456  -1.322397
# 14670   0.948093  -0.225549  -1.752474
# 14671   1.570682   0.474033  -1.023136
#
# [3 rows x 225 columns]

# %% [markdown]
#  check df  percent increase

# %% [markdown]
#  transpose data
# *  changing to wide format

# %%
subset_percent = subset_percent.set_index('RegionName').transpose()

# %%
subset = subset.set_index('RegionName').transpose()

# %%
subset_percent.head(3)
# Out:
# RegionName     95823     95630     95624     95758     95608     95828  \
# 1/31/2004   1.466567  0.806302  1.828975  1.146782  1.618470  1.300149
# 2/29/2004   1.598430  1.233531  1.815326  1.279366  1.513870  1.313381
# 3/31/2004   1.531926  1.311158  1.663032  1.309381  1.629647  1.488055
#
# RegionName     95670     95843     95610     95822  ...     95816     95673  \
# 1/31/2004   1.144742  1.402984  1.186319  1.414288  ...  1.259800  1.447456
# 2/29/2004   1.263717  1.448393  1.260627  1.445511  ...  1.464366  1.250277
# 3/31/2004   1.405681  1.342337  1.422781  1.617514  ...  1.364381  1.827917
#
# RegionName     95817     95814     95626     95811     95683     95693  \
# 1/31/2004   1.346529  1.569793  1.612141  1.308236  1.088360  0.663666
# 2/29/2004   1.737958  1.974921  1.801072  1.460753  1.029991  0.923494
# 3/31/2004   2.085722  2.072492  0.847274  1.549104  0.786197  0.312755
#
# RegionName     95690     95641
# 1/31/2004   0.767883  1.836959
# 2/29/2004  -0.811240  1.255945
# 3/31/2004   0.058588  0.459543
#
# [3 rows x 43 columns]

# %%
subset.head(3)
# Out:
# RegionName     95823     95630     95624     95758     95608     95828  \
# 12/31/2003  164193.0  252759.0  199456.0  243115.0  205997.0  194670.0
# 1/31/2004   166601.0  254797.0  203104.0  245903.0  209331.0  197201.0
# 2/29/2004   169264.0  257940.0  206791.0  249049.0  212500.0  199791.0
#
# RegionName     95670     95843     95610     95822  ...     95816     95673  \
# 12/31/2003  238307.0  176481.0  216215.0  176131.0  ...  329576.0  195999.0
# 1/31/2004   241035.0  178957.0  218780.0  178622.0  ...  333728.0  198836.0
# 2/29/2004   244081.0  181549.0  221538.0  181204.0  ...  338615.0  201322.0
#
# RegionName     95817     95814     95626     95811     95683     95693  \
# 12/31/2003  179350.0  290739.0  196819.0  268606.0  324433.0  326369.0
# 1/31/2004   181765.0  295303.0  199992.0  272120.0  327964.0  328535.0
# 2/29/2004   184924.0  301135.0  203594.0  276095.0  331342.0  331569.0
#
# RegionName     95690     95641
# 12/31/2003  211751.0  218840.0
# 1/31/2004   213377.0  222860.0
# 2/29/2004   211646.0  225659.0
#
# [3 rows x 43 columns]

# %% [markdown]
#  Let's convert the index to datetime!
#
# *  strftime() function is used to convert to Index using specified date_format.
# *   columns.name=none- names the index, by default it is None or blank, the columns are of type IndexArray

# %%
subset_percent.index = p.DatetimeIndex(subset_percent.index)
subset_percent.index = subset_percent.index.strftime('%m/%Y')
subset_percent.columns.name = None

# %%
subset.index = p.DatetimeIndex(subset.index)
subset.index = subset.index.strftime('%m/%Y')
subset.columns.name = None

# %% [markdown]
#  exporting 🥒

# %%
with open('pickle/timeseries_twobedroom_subset_percent.pkl', 'wb') as fp:
    pickle.dump(subset_percent, fp)

# %%
with open('pickle/timeseries_twobedroom_subset.pkl', 'wb') as fp:
    pickle.dump(subset, fp)
