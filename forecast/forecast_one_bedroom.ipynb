# %% [markdown]
#  imports

# %%
# %reload_ext autoreload
# %autoreload 2
import warnings
from statsmodels.tools.sm_exceptions import ConvergenceWarning
warnings.simplefilter('ignore', ConvergenceWarning)
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('fivethirtyeight')
import seaborn as sns
import pickle
#from SCRIPT.eval_tools import *
from statsmodels.tsa.arima_model import ARIMA
from statsmodels.tsa.statespace.sarimax import SARIMAX

# %% [markdown]
# from SCRIPT.eval_tools import * is python 2.o. install newer version

# %%
pip install scripts
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# let's load some data!

# %%
with open('pickle/timeseries_one_bedroom_subset_percent.pkl', 'rb') as fp:
    subset_percent = pickle.load(fp)
    
    subset_percent.index = pd.DatetimeIndex(subset_percent.index.values, freq='infer')
    subset_percent.columns = subset_percent.columns.astype(str)

# %% [markdown]
# enclose index of zips

# %%
select_zipcode = ['95628', '95835', '95833', '95838', '95820', '95825', '95815', '95818', '95816', '95817', 
                  '95811']

# %% [markdown]
# separate out

# %%
zip_1 = select_zipcode[0]
sel_df1 = subset_percent[zip_1]
zip_2 = select_zipcode[1]
sel_df2 = subset_percent[zip_2]
zip_3 = select_zipcode[2]
sel_df3 = subset_percent[zip_3]
zip_4 = select_zipcode[3]
sel_df4 = subset_percent[zip_4]
zip_5 = select_zipcode[4]
sel_df5 = subset_percent[zip_5]
zip_6 = select_zipcode[5]
sel_df6 = subset_percent[zip_6]
zip_7 = select_zipcode[6]
sel_df7 = subset_percent[zip_7]
zip_8 = select_zipcode[7]
sel_df8 = subset_percent[zip_8]
zip_9 = select_zipcode[8]
sel_df9 = subset_percent[zip_9]
zip_10 = select_zipcode[9]
sel_df10 = subset_percent[zip_10]
zip_11 = select_zipcode[10]
sel_df11 = subset_percent[zip_11]

# %% [markdown]
# next we will generate forecast from each zip. later we will combine

# %% [markdown]
# zip code 1

# %%
pdq = (1, 0, 0)
SPDQ = (1, 0, 1, 12)

# %% [markdown]
# -configured hyperparameters (above)
#
# -trend elements
# * pdq=
# * p: Trend autoregression order.
# * d: Trend difference order.
# * q: Trend moving average order.
#
# -seasonal Elements
# * spdq=
# * P: Seasonal autoregressive order.
# * D: Seasonal difference order.
# * Q: Seasonal moving average order.
# * S: The number of time steps for a single seasonal period.

# %% [markdown]
# define model and fit

# %%
sarima = SARIMAX(sel_df1, order=pdq, 
        seasonal_order=SPDQ, 
        enforce_stationarity=False, # Whether or not to transform the AR parameters to 
                 #enforce stationarity in the autoregressive component of the model.
        enforce_invertibility=False)
sarima_model1 = sarima.fit()

# %% [markdown]
# definitions for above
# * seasonal_order = The (P,D,Q,s) order of the seasonal component of the model for the AR parameters, differences, MA parameters, and periodicity.
# * enforce_stationary = Whether or not to transform the AR parameters to enforce stationarity in the autoregressive component of the model. Default is True.
# * enforce_invertability = Whether or not to transform the MA (Moving average) parameters to enforce invertibility in the moving average component of the model.

# %% [markdown]
# make prediction using .forecast function

# %%
pred1 = sarima_model1.forecast(steps = 3*12)

# %% [markdown]
# zip 2

# %%
pdq = (1, 1, 1)
SPDQ = (1, 0, 1, 12)

# %%
sarima = SARIMAX(sel_df2, order=pdq, 
        seasonal_order=SPDQ, 
        enforce_stationarity=False, 
        enforce_invertibility=False)
sarima_model2 = sarima.fit()

# %%
pred2 = sarima_model2.forecast(steps = 3*12)

# %% [markdown]
# zip 3

# %%
pdq = (1, 0, 0)
SPDQ = (1, 1, 1, 12)

# %%
sarima = SARIMAX(sel_df3, order=pdq, 
        seasonal_order=SPDQ, 
        enforce_stationarity=False, 
        enforce_invertibility=False)
sarima_model3 = sarima.fit()

# %%
pred3 = sarima_model3.forecast(steps = 3*12)

# %% [markdown]
# zip 4

# %%
pdq = (0, 1, 0)
SPDQ = (0, 0, 1, 12)

# %%
sarima = SARIMAX(sel_df4, order=pdq, 
        seasonal_order=SPDQ, 
        enforce_stationarity=False, 
        enforce_invertibility=False)
sarima_model4 = sarima.fit()

# %%
pred4 = sarima_model4.forecast(steps = 3*12)

# %% [markdown]
# zip 5

# %%
pdq = (1, 1, 1)
SPDQ = (0, 1, 1, 12)

# %%
sarima = SARIMAX(sel_df5, order=pdq, 
        seasonal_order=SPDQ, 
        enforce_stationarity=False, 
        enforce_invertibility=False)
sarima_model5 = sarima.fit()

# %%
pred5 = sarima_model5.forecast(steps = 3*12)

# %% [markdown]
# zip 6

# %%
pdq = (1, 1, 1)
SPDQ = (1, 0, 1, 12)

# %%
sarima = SARIMAX(sel_df6, order=pdq, 
        seasonal_order=SPDQ, 
        enforce_stationarity=False, 
        enforce_invertibility=False)
sarima_model6 = sarima.fit()

# %%
pred6 = sarima_model6.forecast(steps = 3*12)

# %% [markdown]
# zip 7

# %%
pdq = (1, 1, 1)
SPDQ = (0, 1, 1, 12)

# %%
sarima = SARIMAX(sel_df7, order=pdq, 
        seasonal_order=SPDQ, 
        enforce_stationarity=False, 
        enforce_invertibility=False)
sarima_model7 = sarima.fit()

# %%
pred7 = sarima_model7.forecast(steps = 3*12)

# %% [markdown]
# zip 8

# %%
pdq = (1, 0, 1)
SPDQ = (0, 1, 1, 12)

# %%
sarima = SARIMAX(sel_df8, order=pdq, 
        seasonal_order=SPDQ, 
        enforce_stationarity=False, 
        enforce_invertibility=False)
sarima_model8 = sarima.fit()

# %%
pred8 = sarima_model8.forecast(steps = 3*12)

# %% [markdown]
# zip 9

# %%
pdq = (1, 0, 1)
SPDQ = (0, 1, 1, 12)

# %%
sarima = SARIMAX(sel_df9, order=pdq, 
        seasonal_order=SPDQ, 
        enforce_stationarity=False, 
        enforce_invertibility=False)
sarima_model9 = sarima.fit()

# %%
pred9 = sarima_model9.forecast(steps = 3*12)

# %% [markdown]
# zip 10

# %%
pdq = (1, 0, 1)
SPDQ = (0, 1, 1, 12)

# %%
sarima = SARIMAX(sel_df10, order=pdq, 
        seasonal_order=SPDQ, 
        enforce_stationarity=False, 
        enforce_invertibility=False)
sarima_model10 = sarima.fit()

# %%
pred10 = sarima_model10.forecast(steps = 3*12)

# %% [markdown]
# zip 11

# %%
pdq = (1, 0, 0)
SPDQ = (0, 1, 1, 12)

# %%
sarima = SARIMAX(sel_df11, order=pdq, 
        seasonal_order=SPDQ, 
        enforce_stationarity=False, 
        enforce_invertibility=False)
sarima_model11 = sarima.fit()

# %%
pred11 = sarima_model11.forecast(steps = 3*12)

# %% [markdown]
# plotting out percent of increase

# %%
fig = plt.figure(figsize = (12, 7),facecolor='#d2ae6c')

plt.plot(sel_df1.loc['2014-01-01':], lw = 2, color = '#2E86C1')
plt.plot(sel_df2.loc['2014-01-01':], lw = 2, color = '#40E0D0')
plt.plot(sel_df3.loc['2014-01-01':], lw = 2, color = '#99751b')
plt.plot(sel_df4.loc['2014-01-01':], lw = 2, color = '#D8D051')
plt.plot(sel_df5.loc['2014-01-01':], lw = 2, color = '#A569BD')

plt.plot(pred1, ls = 'dotted', lw = 4, color = '#2E86C1', label = select_zipcode[0])
plt.plot(pred2, ls = 'dotted', lw = 4, color = '#40E0D0', label = select_zipcode[1])
plt.plot(pred3, ls = 'dotted', lw = 4, color = '#99751b', label = select_zipcode[2])
plt.plot(pred4, ls = 'dotted', lw = 4, color = '#D8D051', label = select_zipcode[3])
plt.plot(pred5, ls = 'dotted', lw = 4, color = '#A569BD', label = select_zipcode[4])

plt.axhline(y=0, lw = 1, color = 'black', ls = '--')
plt.xlabel('Year', fontsize=18)
plt.ylabel('Percent', fontsize=18)
plt.title('1 Bedroom Percent Forecast for Top 5 Zip Codes')
#plt.legend(bbox_to_anchor = (1,1), fontsize = 12,facecolor='#E5E7E9' , framealpha=1)
#plt.xticks(rotation = 30)

plt.grid(linestyle='--', linewidth = '1',color='#839192')
plt.show()

# %%
fig = plt.figure(figsize = (12, 7),facecolor='#d2ae6c')

plt.plot(sel_df6.loc['2014-01-01':], lw =2, color = '#2E86C1')
plt.plot(sel_df7.loc['2014-01-01':], lw = 2, color = '#40E0D0')
plt.plot(sel_df8.loc['2014-01-01':], lw = 2, color = '#99751b')
plt.plot(sel_df9.loc['2014-01-01':], lw = 2, color = '#D8D051')
plt.plot(sel_df10.loc['2014-01-01':], lw =2, color = '#A569BD')
plt.plot(sel_df11.loc['2014-01-01':], lw =2, color = '#3AB227')


plt.plot(pred6, ls = 'dotted', lw = 4, color = '#2E86C1', label = select_zipcode[5])
plt.plot(pred7, ls = 'dotted', lw = 4, color = '#40E0D0', label = select_zipcode[6])
plt.plot(pred8, ls = 'dotted', lw = 4, color = '#99751b', label = select_zipcode[7])
plt.plot(pred9, ls = 'dotted', lw = 4, color = '#D8D051', label = select_zipcode[8])
plt.plot(pred10, ls = 'dotted', lw =4, color = '#A569BD', label = select_zipcode[9])
plt.plot(pred11, ls = 'dotted', lw =4, color = '#3AB227', label = select_zipcode[10])

plt.axhline(y=0, lw = 1, color = 'black', ls = '--')
plt.xlabel('Year', fontsize=18)
plt.ylabel('Percent', fontsize=18)
plt.title('1 Bedroom Percent Forecast for Remaining 6 Zip Codes', fontsize= 22 )
#plt.legend(bbox_to_anchor = (1,1), fontsize = 13,facecolor ='#E5E7E9' , framealpha = 1)

plt.grid(linestyle='--', linewidth = '1',color='#839192')
plt.show()

# %% [markdown]
#  importData with  🥒

# %%
with open('pickle/timeseries_one_bedroom_subset.pkl', 'rb') as fp:
    subset = pickle.load(fp)
    
subset.index = pd.DatetimeIndex(subset.index.values, freq='infer')
subset.columns = subset.columns.astype(str)

# %% [markdown]
# define function compute housing price

# %%
def compute_housing_price(zip_, pred):
    last_val = subset[zip_][-1]
    prices = []
    for rate in pred:
        current = last_val * (1 + rate/100)
        prices.append(current)
        last_val = current
    return prices

# %%
price1 = compute_housing_price(select_zipcode[0], pred1)
price2 = compute_housing_price(select_zipcode[1], pred2)
price3 = compute_housing_price(select_zipcode[2], pred3)
price4 = compute_housing_price(select_zipcode[3], pred4)
price5 = compute_housing_price(select_zipcode[4], pred5)
price6 = compute_housing_price(select_zipcode[5], pred6)
price7 = compute_housing_price(select_zipcode[6], pred7)
price8 = compute_housing_price(select_zipcode[7], pred8)
price9 = compute_housing_price(select_zipcode[8], pred9)
price10 = compute_housing_price(select_zipcode[9], pred10)
price11 = compute_housing_price(select_zipcode[10], pred11)

# %% [markdown]
# plotting out

# %%
fig = plt.figure(figsize = (12, 7),facecolor='darkseagreen')

plt.plot(subset[select_zipcode[0]].loc['2014-01-01':], lw = 3, color = '#2E86C1')
plt.plot(subset[select_zipcode[1]].loc['2014-01-01':], lw = 3, color = '#40E0D0')
plt.plot(subset[select_zipcode[2]].loc['2014-01-01':], lw = 3, color = '#99751b')
plt.plot(subset[select_zipcode[3]].loc['2014-01-01':], lw = 3, color = '#D8D051')
plt.plot(subset[select_zipcode[4]].loc['2014-01-01':], lw = 3, color = '#A569BD')

plt.plot(pred1.index, price1, ls = 'dotted', lw = 5, color = '#2E86C1', label = select_zipcode[0])
plt.plot(pred2.index, price2, ls = 'dotted', lw = 5, color = '#40E0D0', label = select_zipcode[1])
plt.plot(pred3.index, price3, ls = 'dotted', lw = 5, color = '#99751b', label = select_zipcode[2])
plt.plot(pred4.index, price4, ls = 'dotted', lw = 5, color = '#D8D051', label = select_zipcode[3])
plt.plot(pred5.index, price5, ls = 'dotted', lw = 5, color = '#A569BD', label = select_zipcode[4])

plt.xlabel('Year', color = 'black', fontsize=20)
plt.ylabel('Housing Price',color='black', fontsize=20)
plt.title('1 Bedroom Price Forecast of Top 5 Zip Codes', fontsize = 22)
#plt.legend(bbox_to_anchor = (.95,.95), fontsize = 16,facecolor='#E5E7E9' , framealpha=1)

plt.grid(linestyle='--', linewidth = '1',color='#839192')
plt.show()

# %%
fig = plt.figure(figsize = (12, 7), facecolor='darkseagreen')

plt.plot(subset[select_zipcode[5]].loc['2014-01-01':], lw = 3, color = '#2E86C1')
plt.plot(subset[select_zipcode[6]].loc['2014-01-01':], lw = 3, color = '#40E0D0')
plt.plot(subset[select_zipcode[7]].loc['2014-01-01':], lw = 3, color = '#99751b')
plt.plot(subset[select_zipcode[8]].loc['2014-01-01':], lw = 3, color = '#D8D051')
plt.plot(subset[select_zipcode[9]].loc['2014-01-01':], lw = 3, color = '#A569BD')
plt.plot(subset[select_zipcode[10]].loc['2014-01-01':], lw = 3, color = '#3AB227')

plt.plot(pred1.index, price6, ls = 'dotted', lw = 5, color = '#2E86C1', label = select_zipcode[5])
plt.plot(pred2.index, price7, ls = 'dotted', lw = 5, color = '#40E0D0', label = select_zipcode[6])
plt.plot(pred3.index, price8, ls = 'dotted', lw = 5, color = '#99751b', label = select_zipcode[7])
plt.plot(pred4.index, price9, ls = 'dotted', lw = 5, color = '#D8D051', label = select_zipcode[8])
plt.plot(pred5.index, price10, ls = 'dotted', lw = 5, color = '#A569BD', label = select_zipcode[9])
plt.plot(pred1.index, price11, ls = 'dotted', lw = 6, color = '#3AB227', label = select_zipcode[10])

plt.xlabel('Year', color = 'black', fontsize=20)
plt.ylabel('Housing Price',color='black', fontsize=20)
plt.title('1 Bedroom Price Forecast for Remaining 6 Zip Codes',
          fontsize = 22)
#plt.legend(bbox_to_anchor = (.97,.95), fontsize = 16,facecolor='#E5E7E9' , framealpha=1)
#plt.xticks(rotation = 30)

plt.grid(linestyle='--', linewidth = '1',color='#839192')
plt.show()

# %%
fig = plt.figure(figsize = (12, 7),facecolor='darkseagreen')

plt.plot(subset[select_zipcode[0]].loc['2014-01-01':], lw = 3, color = '#2E86C1')
plt.plot(subset[select_zipcode[1]].loc['2014-01-01':], lw = 3, color = '#2E86C1')
plt.plot(subset[select_zipcode[2]].loc['2014-01-01':], lw = 3, color = '#D8D051')
plt.plot(subset[select_zipcode[3]].loc['2014-01-01':], lw = 3, color = '#2E86C1')
plt.plot(subset[select_zipcode[4]].loc['2014-01-01':], lw = 3, color = '#2E86C1')
plt.plot(subset[select_zipcode[5]].loc['2014-01-01':], lw = 3, color = '#2E86C1')
plt.plot(subset[select_zipcode[6]].loc['2014-01-01':], lw = 3, color = '#D8D051')
plt.plot(subset[select_zipcode[7]].loc['2014-01-01':], lw = 3, color = '#D8D051')
plt.plot(subset[select_zipcode[8]].loc['2014-01-01':], lw = 3, color = '#D8D051')
plt.plot(subset[select_zipcode[9]].loc['2014-01-01':], lw = 3, color = '#D8D051')
plt.plot(subset[select_zipcode[10]].loc['2014-01-01':], lw = 3, color ='#D8D051')

plt.plot(pred1.index, price1, ls = 'dotted', lw = 5, color = '#2E86C1', label = select_zipcode[0])
plt.plot(pred2.index, price2, ls = 'dotted', lw = 5, color = '#2E86C1', label = select_zipcode[1])
plt.plot(pred3.index, price3, ls = 'dotted', lw = 5, color = '#D8D051', label = select_zipcode[2])
plt.plot(pred4.index, price4, ls = 'dotted', lw = 5, color = '#2E86C1', label = select_zipcode[3])
plt.plot(pred5.index, price5, ls = 'dotted', lw = 5, color = '#2E86C1', label = select_zipcode[4])
plt.plot(pred1.index, price6, ls = 'dotted', lw = 5, color = '#2E86C1', label = select_zipcode[5])
plt.plot(pred2.index, price7, ls = 'dotted', lw = 5, color = '#D8D051', label = select_zipcode[6])
plt.plot(pred3.index, price8, ls = 'dotted', lw = 5, color = '#D8D051', label = select_zipcode[7])
plt.plot(pred4.index, price9, ls = 'dotted', lw = 5, color = '#D8D051', label = select_zipcode[8])
plt.plot(pred5.index, price10, ls = 'dotted', lw = 5, color = '#D8D051', label = select_zipcode[9])
plt.plot(pred1.index, price11, ls = 'dotted', lw = 5, color = '#D8D051', label = select_zipcode[10])

plt.xlabel('Year', color = 'black', fontsize=21)
plt.ylabel('Housing Price',color='black', fontsize=21)
plt.title('1 Bedroom Price Forecast for All Zip Codes',
          fontsize = 22)
plt.legend(bbox_to_anchor = (1,1), fontsize = 16,facecolor='#E5E7E9' , framealpha=1)

plt.grid(linestyle='--', linewidth = '1',color='#839192')
plt.show()
