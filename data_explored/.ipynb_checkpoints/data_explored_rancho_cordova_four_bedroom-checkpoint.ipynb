# %% [markdown]
#  import libraries

# %%
# %reload_ext autoreload
# %autoreload 2

import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('fivethirtyeight')

import seaborn as sns

import pickle
##from SCRIPT.eval_tools import *

# %% [markdown]
#  let's load some data! 🥒

# %%
with open('pickle/timeseries_rancho_four_bedroom_subset_percent.pkl', 'rb') as fp:
    subset_percent = pickle.load(fp)

# %%
with open('pickle/timeseries_rancho_four_bedroom_subset.pkl', 'rb') as fp:
    subset = pickle.load(fp)

# %%
subset.head(4)
# Out:
#             95670     95827     95742     95655
# 02/2006  455487.0  390001.0  513210.0  471734.0
# 03/2006  455048.0  389407.0  511707.0  471892.0
# 04/2006  456021.0  390268.0  511761.0  473201.0
# 05/2006  455234.0  389828.0  509093.0  473391.0

# %%
subset_percent.head()
# Out:
#             95670     95827     95742     95655
# 03/2006 -0.096380 -0.152307 -0.292863  0.033493
# 04/2006  0.213824  0.221105  0.010553  0.277394
# 05/2006 -0.172580 -0.112743 -0.521337  0.040152
# 06/2006 -0.037783 -0.057205  0.187392  0.217790
# 07/2006 -0.455982 -0.566471  0.321147 -0.152185

# %% [markdown]
#   train test split

# %%
trdf_percent = subset_percent.iloc[:-40]
trdf_percent.index = pd.to_datetime(trdf_percent.index)

# %%
trdf_price = subset.iloc[:-40]
trdf_price.index = pd.to_datetime(trdf_price.index)

# %% [markdown]
#  Average Percent Increase of Housing Price

# %%
subset_percent.head(3)
# Out:
#             95670     95827     95742     95655
# 03/2006 -0.096380 -0.152307 -0.292863  0.033493
# 04/2006  0.213824  0.221105  0.010553  0.277394
# 05/2006 -0.172580 -0.112743 -0.521337  0.040152

# %%
mean = np.mean(subset_percent, axis = 1)
ax = mean.plot(figsize = (10, 6))
plt.ylabel('Percent Increase')
plt.title('Average Percent Increase of House Price')
plt.show()

# %% [markdown]
# Average Housing Price

# %%
price_mean = np.mean(subset, axis = 1)
ax = price_mean.plot(figsize = (10, 6))
plt.ylabel('Housing Price ($)')
plt.title('Average House Price')
plt.show()

# %% [markdown]
#  Percent Increase All Zip Codes

# %%
subset_percent.plot(figsize = (10, 4), lw = 1, color = 'brown', alpha = 0.5)
mean.plot(c = 'black', lw = 3)
plt.legend().set_visible(False)
plt.ylabel('Percent Increase All Zip Codes')
plt.show()

# %% [markdown]
#  Housing Price ($) All Zip Codes

# %%
subset.head(23)
# Out:
#             95670     95827     95742     95655
# 02/2006  455487.0  390001.0  513210.0  471734.0
# 03/2006  455048.0  389407.0  511707.0  471892.0
# 04/2006  456021.0  390268.0  511761.0  473201.0
# 05/2006  455234.0  389828.0  509093.0  473391.0
# 06/2006  455062.0  389605.0  510047.0  474422.0
# 07/2006  452987.0  387398.0  511685.0  473700.0
# 08/2006  451217.0  385443.0  514567.0  472906.0
# 09/2006  447103.0  382107.0  512292.0  470285.0
# 10/2006  440447.0  377020.0  505294.0  464314.0
# 11/2006  434965.0  373043.0  498762.0  459030.0
# 12/2006  428603.0  368309.0  491297.0  452190.0
# 01/2007  423958.0  364611.0  485830.0  448459.0
# 02/2007  420325.0  361240.0  482910.0  446109.0
# 03/2007  418212.0  358550.0  481062.0  445902.0
# 04/2007  416449.0  356857.0  478003.0  446584.0
# 05/2007  411833.0  352540.0  470704.0  443569.0
# 06/2007  405435.0  347626.0  463269.0  437060.0
# 07/2007  399015.0  341985.0  457655.0  428898.0
# 08/2007  393086.0  337629.0  453745.0  422086.0
# 09/2007  387968.0  333416.0  449035.0  418440.0
# 10/2007  380277.0  325721.0  439160.0  409978.0
# 11/2007  372424.0  316832.0  428700.0  400787.0
# 12/2007  368184.0  311152.0  424108.0  394737.0

# %%
subset.plot(figsize = (12, 6), lw = 1, color = 'brown', alpha = 0.5)
price_mean.plot(c = 'black', lw = 3)
plt.legend().set_visible(False)
plt.ylabel('Rancho Cordova 4 Bedroom Price ($) All Zip Codes')
plt.show()

# %% [markdown]
#  areas against the trend

# %% [markdown]
#  calculate absolute difference

# %%
diff_df = trdf_price.apply(lambda x: abs(x-mean))

# %% [markdown]
#  top 4 zipcodes with odd trends

# %%
diffs = np.sum(diff_df, axis = 0).sort_values(ascending = False)
select_zipcodes = list(diffs.index[0:3])
print(f'top 4 zipcodes with odd trends: {select_zipcodes}')
# Out:
# top 4 zipcodes with odd trends: [95670, 95827, 95742]

# %% [markdown]
#  zip closest to average

# %%
print(f'closest to the average: {diffs.index[-2]}')
# Out:
# closest to the average: 95742
