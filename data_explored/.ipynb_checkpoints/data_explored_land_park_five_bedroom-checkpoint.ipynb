# %% [markdown]
#  import libraries

# %%
# %reload_ext autoreload
# %autoreload 2

import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('fivethirtyeight')

import seaborn as sns

import pickle
##from SCRIPT.eval_tools import *

# %% [markdown]
#  let's load some data! 🥒

# %%
with open('pickle/timeseries_land_park_five_bedroom_subset_percent.pkl', 'rb') as fp:
    subset_percent = pickle.load(fp)

# %%
with open('pickle/timeseries_land_park_five_bedroom_subset.pkl', 'rb') as fp:
    subset = pickle.load(fp)

# %%
subset.head()
# Out:
#             95630     95624     95818     95819
# 01/2000  348238.0  239287.0  194506.0  138407.0
# 02/2000  349577.0  240279.0  196055.0  139184.0
# 03/2000  351199.0  241601.0  197607.0  140067.0
# 04/2000  354037.0  243729.0  200047.0  141140.0
# 05/2000  357528.0  245949.0  202376.0  142906.0

# %%
subset_percent.head()
# Out:
#             95630     95624     95818     95819
# 02/2000  0.384507  0.414565  0.796376  0.561388
# 03/2000  0.463989  0.550194  0.791615  0.634412
# 04/2000  0.808089  0.880791  1.234774  0.766062
# 05/2000  0.986055  0.910848  1.164226  1.251240
# 06/2000  0.863988  0.981504  0.275230  1.069934

# %% [markdown]
#   train test split

# %%
trdf_percent = subset_percent.iloc[:-40]
trdf_percent.index = pd.to_datetime(trdf_percent.index)

# %%
trdf_price = subset.iloc[:-40]
trdf_price.index = pd.to_datetime(trdf_price.index)

# %% [markdown]
#  Average Percent Increase of Housing Price

# %%
subset_percent.head()
# Out:
#             95630     95624     95818     95819
# 02/2000  0.384507  0.414565  0.796376  0.561388
# 03/2000  0.463989  0.550194  0.791615  0.634412
# 04/2000  0.808089  0.880791  1.234774  0.766062
# 05/2000  0.986055  0.910848  1.164226  1.251240
# 06/2000  0.863988  0.981504  0.275230  1.069934

# %%
mean = np.mean(subset_percent, axis = 1)
ax = mean.plot(figsize = (10, 6))
plt.ylabel('Percent Increase')
plt.title('Average Percent Increase of House Price')
plt.show()

# %% [markdown]
# Average Housing Price

# %%
price_mean = np.mean(subset, axis = 1)
ax = price_mean.plot(figsize = (10, 6))
plt.ylabel('Housing Price ($)')
plt.title('Average House Price')
plt.show()

# %% [markdown]
#  Percent Increase All Zip Codes

# %%
subset_percent.plot(figsize = (10, 4), lw = 1, color = 'brown', alpha = 0.5)
mean.plot(c = 'black', lw = 3)
plt.legend().set_visible(False)
plt.ylabel('Percent Increase All Zip Codes')
plt.show()

# %% [markdown]
#  Housing Price ($) All Zip Codes

# %%
subset.head(23)
# Out:
#             95630     95624     95818     95819
# 01/2000  348238.0  239287.0  194506.0  138407.0
# 02/2000  349577.0  240279.0  196055.0  139184.0
# 03/2000  351199.0  241601.0  197607.0  140067.0
# 04/2000  354037.0  243729.0  200047.0  141140.0
# 05/2000  357528.0  245949.0  202376.0  142906.0
# 06/2000  360617.0  248363.0  202933.0  144435.0
# 07/2000  365232.0  250959.0  206037.0  146251.0
# 08/2000  368961.0  253741.0  209308.0  147122.0
# 09/2000  373433.0  256325.0  214076.0  149186.0
# 10/2000  377536.0  259425.0  217924.0  152242.0
# 11/2000  383756.0  262873.0  223048.0  154550.0
# 12/2000  390149.0  266658.0  228163.0  158200.0
# 01/2001  397025.0  270831.0  233780.0  162151.0
# 02/2001  403072.0  274995.0  239981.0  167165.0
# 03/2001  409440.0  279112.0  246980.0  170602.0
# 04/2001  416725.0  284071.0  254738.0  174182.0
# 05/2001  425070.0  289278.0  260207.0  178600.0
# 06/2001  434167.0  295408.0  266677.0  182217.0
# 07/2001  442004.0  301120.0  269326.0  183818.0
# 08/2001  447188.0  306495.0  273025.0  185341.0
# 09/2001  450761.0  310359.0  273575.0  186326.0
# 10/2001  453283.0  312842.0  275091.0  187927.0
# 11/2001  456201.0  314746.0  275964.0  188778.0

# %%
subset.plot(figsize = (12, 6), lw = 1, color = 'brown', alpha = 0.5)
price_mean.plot(c = 'black', lw = 3)
plt.legend().set_visible(False)
plt.ylabel('5 Bedroom Price ($) All Zip Codes')
plt.show()

# %% [markdown]
#  areas against the trend

# %% [markdown]
#  calculate absolute difference

# %%
diff_df = trdf_price.apply(lambda x: abs(x-mean))

# %% [markdown]
#  top 4 zipcodes with odd trends

# %%
diffs = np.sum(diff_df, axis = 0).sort_values(ascending = False)
select_zipcodes = list(diffs.index[0:4])
print(f'top 4 zipcodes with odd trends: {select_zipcodes}')
# Out:
# top 4 zipcodes with odd trends: [95630, 95624, 95818, 95819]

# %% [markdown]
#  zip closest to average

# %%
print(f'closest to the average: {diffs.index[-2]}')
# Out:
# closest to the average: 95818
