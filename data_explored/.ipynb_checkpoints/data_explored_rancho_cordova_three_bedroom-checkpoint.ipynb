# %% [markdown]
#  import libraries

# %%
# %reload_ext autoreload
# %autoreload 2

import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('fivethirtyeight')

import seaborn as sns

import pickle
##from SCRIPT.eval_tools import *

# %% [markdown]
#  let's load some data! 🥒

# %%
with open('pickle/timeseries_rancho_three_bedroom_subset_percent.pkl', 'rb') as fp:
    subset_percent = pickle.load(fp)

# %%
with open('pickle/timeseries_rancho_three_bedroom_subset.pkl', 'rb') as fp:
    subset = pickle.load(fp)

# %%
subset.head(4)
# Out:
#             95670     95827     95742     95655
# 01/2010  195701.0  167653.0  253390.0  206751.0
# 02/2010  194468.0  167440.0  252525.0  206515.0
# 03/2010  194310.0  168903.0  252042.0  206315.0
# 04/2010  193087.0  168720.0  250260.0  205086.0

# %%
subset_percent.head()
# Out:
#             95670     95827     95742     95655
# 02/2010 -0.630043 -0.127048 -0.341371 -0.114147
# 03/2010 -0.081247  0.873746 -0.191268 -0.096845
# 04/2010 -0.629407 -0.108346 -0.707025 -0.595691
# 05/2010  0.138280  0.136321 -0.540638 -0.161883
# 06/2010 -0.478914 -0.375259 -0.809941 -0.247126

# %% [markdown]
#   train test split

# %%
trdf_percent = subset_percent.iloc[:-40]
trdf_percent.index = pd.to_datetime(trdf_percent.index)

# %%
trdf_price = subset.iloc[:-40]
trdf_price.index = pd.to_datetime(trdf_price.index)

# %% [markdown]
#  Average Percent Increase of Housing Price

# %%
subset_percent.head(4)
# Out:
#             95670     95827     95742     95655
# 02/2010 -0.630043 -0.127048 -0.341371 -0.114147
# 03/2010 -0.081247  0.873746 -0.191268 -0.096845
# 04/2010 -0.629407 -0.108346 -0.707025 -0.595691
# 05/2010  0.138280  0.136321 -0.540638 -0.161883

# %%
mean = np.mean(subset_percent, axis = 1)
ax = mean.plot(figsize = (10, 6))
plt.ylabel('Percent Increase')
plt.title('Average Percent Increase of House Price')
plt.show()

# %% [markdown]
# Average Housing Price

# %%
price_mean = np.mean(subset, axis = 1)
ax = price_mean.plot(figsize = (10, 6))
plt.ylabel('Housing Price ($)')
plt.title('Average House Price')
plt.show()

# %% [markdown]
#  Percent Increase All Zip Codes

# %%
subset_percent.plot(figsize = (10, 4), lw = 1, color = 'brown', alpha = 0.5)
mean.plot(c = 'black', lw = 3)
plt.legend().set_visible(False)
plt.ylabel('Percent Increase All Zip Codes')
plt.show()

# %% [markdown]
#  Housing Price ($) All Zip Codes

# %%
subset.head(23)
# Out:
#             95670     95827     95742     95655
# 01/2010  195701.0  167653.0  253390.0  206751.0
# 02/2010  194468.0  167440.0  252525.0  206515.0
# 03/2010  194310.0  168903.0  252042.0  206315.0
# 04/2010  193087.0  168720.0  250260.0  205086.0
# 05/2010  193354.0  168950.0  248907.0  204754.0
# 06/2010  192428.0  168316.0  246891.0  204248.0
# 07/2010  192361.0  167534.0  245407.0  203465.0
# 08/2010  190887.0  166216.0  243427.0  202151.0
# 09/2010  188899.0  163718.0  241483.0  199909.0
# 10/2010  186367.0  161358.0  239657.0  198361.0
# 11/2010  184928.0  159521.0  238280.0  196929.0
# 12/2010  184243.0  158965.0  236633.0  196846.0
# 01/2011  183105.0  158203.0  234469.0  195927.0
# 02/2011  180876.0  156611.0  231570.0  193139.0
# 03/2011  177815.0  154199.0  228294.0  190850.0
# 04/2011  175131.0  152069.0  225401.0  188675.0
# 05/2011  172099.0  148956.0  221966.0  186112.0
# 06/2011  169805.0  145678.0  218870.0  182787.0
# 07/2011  167755.0  142912.0  216481.0  180359.0
# 08/2011  166620.0  141378.0  215437.0  179799.0
# 09/2011  165114.0  140348.0  217380.0  180212.0
# 10/2011  162772.0  138641.0  217835.0  179625.0
# 11/2011  159954.0  137236.0  217992.0  178640.0

# %%
subset.plot(figsize = (12, 6), lw = 1, color = 'brown', alpha = 0.5)
price_mean.plot(c = 'black', lw = 3)
plt.legend().set_visible(False)
plt.ylabel('Rancho Cordova 4 Bedroom Price ($) All Zip Codes')
plt.show()

# %% [markdown]
#  areas against the trend

# %% [markdown]
#  calculate absolute difference

# %%
diff_df = trdf_price.apply(lambda x: abs(x-mean))

# %% [markdown]
#  top 4 zipcodes with odd trends

# %%
diffs = np.sum(diff_df, axis = 0).sort_values(ascending = False)
select_zipcodes = list(diffs.index[0:4])
print(f'top 4 zipcodes with odd trends: {select_zipcodes}')
# Out:
# top 4 zipcodes with odd trends: [95670, 95827, 95742, 95655]

# %% [markdown]
#  zip closest to average

# %%
print(f'closest to the average: {diffs.index[-2]}')
# Out:
# closest to the average: 95742
