# %% [markdown]
#  import libraries

# %%
# %reload_ext autoreload
# %autoreload 2

import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('fivethirtyeight')

import seaborn as sns

import pickle
##from SCRIPT.eval_tools import *

# %% [markdown]
#  let's load some data! 🥒

# %%
with open('pickle/timeseries_elk_grove_five_bedroom_subset_percent.pkl', 'rb') as fp:
    subset_percent = pickle.load(fp)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13788\3504919752.py in <module>
# ----> 1 with open('pickle/timeseries_elk_grove_five_bedroom_subset_percent.pkl', 'rb') as fp:
#       2     subset_percent = pickle.load(fp)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'pickle/timeseries_elk_grove_five_bedroom_subset_percent.pkl'

# %%
with open('pickle/timeseries_rancho_five_bedroom_subset.pkl', 'rb') as fp:
    subset = pickle.load(fp)

# %%
subset.head(4)
# Out:
#             95670     95827     95742     95655
# 01/2010  333486.0  238070.0  313032.0  369797.0
# 02/2010  330085.0  237053.0  311804.0  368771.0
# 03/2010  330092.0  239128.0  311828.0  369564.0
# 04/2010  328338.0  237732.0  309800.0  366142.0

# %%
subset_percent.head()
# Out:
#             95670     95827     95742     95655
# 02/2010 -1.019833 -0.427185 -0.392292 -0.277450
# 03/2010  0.002121  0.875332  0.007697  0.215039
# 04/2010 -0.531367 -0.583788 -0.650359 -0.925956
# 05/2010  0.038375 -0.939293 -0.060684 -0.408038
# 06/2010 -0.053887 -0.398728 -0.296823 -0.430552

# %% [markdown]
#   train test split

# %%
trdf_percent = subset_percent.iloc[:-40]
trdf_percent.index = pd.to_datetime(trdf_percent.index)

# %%
trdf_price = subset.iloc[:-40]
trdf_price.index = pd.to_datetime(trdf_price.index)

# %% [markdown]
#  Average Percent Increase of Housing Price

# %%
subset_percent.head(4)
# Out:
#             95670     95827     95742     95655
# 02/2010 -1.019833 -0.427185 -0.392292 -0.277450
# 03/2010  0.002121  0.875332  0.007697  0.215039
# 04/2010 -0.531367 -0.583788 -0.650359 -0.925956
# 05/2010  0.038375 -0.939293 -0.060684 -0.408038

# %%
mean = np.mean(subset_percent, axis = 1)
ax = mean.plot(figsize = (10, 6))
plt.ylabel('Percent Increase')
plt.title('Average Percent Increase of House Price')
plt.show()

# %% [markdown]
# Average Housing Price

# %%
price_mean = np.mean(subset, axis = 1)
ax = price_mean.plot(figsize = (10, 6))
plt.ylabel('Housing Price ($)')
plt.title('Average House Price')
plt.show()

# %% [markdown]
#  Percent Increase All Zip Codes

# %%
subset_percent.plot(figsize = (10, 4), lw = 1, color = 'brown', alpha = 0.5)
mean.plot(c = 'black', lw = 3)
plt.legend().set_visible(False)
plt.ylabel('Percent Increase All Zip Codes')
plt.show()

# %% [markdown]
#  Housing Price ($) All Zip Codes

# %%
subset.head(23)
# Out:
#             95670     95827     95742     95655
# 01/2010  333486.0  238070.0  313032.0  369797.0
# 02/2010  330085.0  237053.0  311804.0  368771.0
# 03/2010  330092.0  239128.0  311828.0  369564.0
# 04/2010  328338.0  237732.0  309800.0  366142.0
# 05/2010  328464.0  235499.0  309612.0  364648.0
# 06/2010  328287.0  234560.0  308693.0  363078.0
# 07/2010  326986.0  234411.0  308802.0  361366.0
# 08/2010  324287.0  235005.0  307347.0  358146.0
# 09/2010  316454.0  230369.0  305170.0  346853.0
# 10/2010  310005.0  225154.0  303323.0  334314.0
# 11/2010  304686.0  221412.0  302212.0  323557.0
# 12/2010  304170.0  220938.0  301637.0  321440.0
# 01/2011  303772.0  221860.0  300225.0  320851.0
# 02/2011  302000.0  220763.0  296909.0  317161.0
# 03/2011  300111.0  217881.0  293229.0  312204.0
# 04/2011  298129.0  215055.0  289795.0  307801.0
# 05/2011  294674.0  212202.0  286483.0  302497.0
# 06/2011  290501.0  210314.0  283459.0  297464.0
# 07/2011  286656.0  207833.0  281959.0  293913.0
# 08/2011  285304.0  206342.0  281554.0  292963.0
# 09/2011  284791.0  205161.0  282942.0  294062.0
# 10/2011  282744.0  203009.0  281034.0  292168.0
# 11/2011  279928.0  200743.0  279405.0  291370.0

# %%
subset.plot(figsize = (12, 6), lw = 1, color = 'brown', alpha = 0.5)
price_mean.plot(c = 'black', lw = 3)
plt.legend().set_visible(False)
plt.ylabel('Rancho Cordova 5 Bedroom Price ($) All Zip Codes')
plt.show()

# %% [markdown]
#  areas against the trend

# %% [markdown]
#  calculate absolute difference

# %%
diff_df = trdf_price.apply(lambda x: abs(x-mean))

# %% [markdown]
#  top 4 zipcodes with odd trends

# %%
diffs = np.sum(diff_df, axis = 0).sort_values(ascending = False)
select_zipcodes = list(diffs.index[0:4])
print(f'top 4 zipcodes with odd trends: {select_zipcodes}')
# Out:
# top 4 zipcodes with odd trends: [95670, 95827, 95742, 95655]

# %% [markdown]
#  zip closest to average

# %%
print(f'closest to the average: {diffs.index[-2]}')
# Out:
# closest to the average: 95742
